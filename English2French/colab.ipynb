# %%
import pandas as pd
import math
from transformers import XLMRobertaTokenizer

import torch
import torch.nn as nn
import torch.optim as optim
from torch.nn import Transformer
from torch.utils.data import Dataset, DataLoader

# %%
print("Total entries in dataset:", len(dataset))
# Out:
# Total entries in dataset: 175621

# %%
import math
from torch.utils.data import DataLoader

# Assuming English2FrenchDataset has been defined and imported correctly
dataset = English2FrenchDataset('eng_french.csv', tokenizer, context_window)
print("Total entries in dataset:", len(dataset))

# Set the batch size
batch_size = 256  # You can adjust this based on your dataset size

# Create the DataLoader
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True, drop_last=False)

# Calculate the total number of batches per epoch
total_batches = math.ceil(len(dataset) / batch_size)
print(f"Total number of batches per epoch: {total_batches}")
# Out:
# Total entries in dataset: 175621
# Total number of batches per epoch: 687

# %%
# get the data
# !wget https://raw.githubusercontent.com/southern-cross-ai/TranslationAI/main/English2French/eng_french.csv
# Out:
# --2024-04-29 01:20:47--  https://raw.githubusercontent.com/southern-cross-ai/TranslationAI/main/English2French/eng_french.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12497909 (12M) [text/plain]
# Saving to: ‘eng_french.csv’
#
# eng_french.csv      100%[===================>]  11.92M  --.-KB/s    in 0.07s
#
# 2024-04-29 01:20:47 (178 MB/s) - ‘eng_french.csv’ saved [12497909/12497909]

# %%
# Constants
batch_size=128
context_window=512
embedding_size = 512
english = 'English words/sentences'
french = 'French words/sentences'
csv_colums=[english, french]

nhead = 6
num_encoder_layers = 3
num_decoder_layers = 3
dim_feedforward = 2048
dropout = 0.1

# %%
class English2FrenchDataset(Dataset):
    def __init__(self, csv_file, tokenizer, context_window):
        self.dataframe = pd.read_csv(csv_file, usecols=csv_colums)
        self.tokenizer = tokenizer
        self.context_window = context_window

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        source = self.dataframe.iloc[idx][english]
        target = self.dataframe.iloc[idx][french]

        source_encoded = self.tokenizer.encode_plus(
            source,
            max_length = context_window,
            padding='max_length',
            truncation=True,
            return_tensors='pt'
        )
        target_encoded = self.tokenizer.encode_plus(
            target,
            max_length = context_window,
            padding='max_length',
            truncation=True,
            return_tensors='pt'
        )

        # Generate masks for source and target
        source_mask = (source_encoded['input_ids'].squeeze() != self.tokenizer.pad_token_id)
        target_mask = (target_encoded['input_ids'].squeeze() != self.tokenizer.pad_token_id)

        return {
            'source_text': source,
            'source_input_ids': source_encoded['input_ids'].squeeze(),
            'source_mask': source_mask,
            'target_text': target,
            'target_input_ids': target_encoded['input_ids'].squeeze(),
            'target_mask': target_mask
        }

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, embedding_size, dropout=0.1, context_window=512):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)

        position = torch.arange(context_window).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, embedding_size, 2) * -(math.log(10000.0) / embedding_size))
        pe = torch.zeros(context_window, embedding_size)
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:x.size(0), :]
        return self.dropout(x)

# %%
class Model(nn.Module):
    def __init__(self,
                 vocab_size,
                 embedding_size,
                 nhead,
                 num_encoder_layers,
                 num_decoder_layers,
                 dim_feedforward,
                 context_window,
                 dropout=0.1
                 ):
        super(Model, self).__init__()
        self.embedding_size = embedding_size
        self.embedding = nn.Embedding(vocab_size, embedding_size)
        self.pos_encoder = PositionalEncoding(embedding_size, dropout, context_window)
        self.transformer = nn.Transformer(embedding_size,
                                          nhead,
                                          num_encoder_layers,
                                          num_decoder_layers,
                                          dim_feedforward,
                                          dropout)
        self.out = nn.Linear(embedding_size, vocab_size)

    def forward(self, src, tgt, src_key_padding_mask, tgt_key_padding_mask, memory_key_padding_mask=None):
        src = self.embedding(src) * math.sqrt(self.embedding_size)
        src = self.pos_encoder(src)

        tgt = self.embedding(tgt) * math.sqrt(self.embedding_size)
        tgt = self.pos_encoder(tgt)

        output = self.transformer(src,
                                  tgt,
                                  src_key_padding_mask=src_key_padding_mask,
                                  tgt_mask=None,
                                  tgt_key_padding_mask=tgt_key_padding_mask,
                                  memory_key_padding_mask=memory_key_padding_mask
                                  )
        output = self.out(output)
        return output

# %%
# Tokenization
tokenizer = XLMRobertaTokenizer.from_pretrained('xlm-roberta-base');
vocab_size = tokenizer.vocab_size
# Data Preparation
dataset = English2FrenchDataset('eng_french.csv', tokenizer, context_window)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)
# Model
model = Model(vocab_size, embedding_size, nhead, num_encoder_layers, num_decoder_layers, dim_feedforward, context_window, dropout)
# Loss
loss_fn = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)
# Training
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:286: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")

# %%
for i, data in enumerate(dataloader):
    print(f"Batch {i+1}:")
    print(data)
    print(type(data))
    # print(data.shape)
    # if i == 1:  # Print first 2 batches then break
    #     break
# Out:
# Streaming output truncated to the last 5000 lines.
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2591:
# {'source_text': ['Just leave me alone.', "Japan's rice market is closed to imports."], 'source_input_ids': tensor([[    0,  9563, 31358,  ...,     1,     1,     1],
#         [    0, 15758,    25,  ...,     1,     1,     1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ['Fichez-moi simplement la paix !', "Le marché du riz japonais est fermé à l'importation."], 'target_input_ids': tensor([[    0,   563,  9034,  ...,     1,     1,     1],
#         [    0,   636, 35856,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2592:
# {'source_text': ["She didn't try to translate the letter.", 'I want what you want.'], 'source_input_ids': tensor([[    0,  4687, 15935,  ...,     1,     1,     1],
#         [    0,    87,  3444,  ...,     1,     1,     1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ["Elle n'essaya pas de traduire la lettre.", 'Je veux ce que tu veux.'], 'target_input_ids': tensor([[    0, 14663,   653,  ...,     1,     1,     1],
#         [    0,   845, 54226,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2593:
# {'source_text': ["This is a book of children's stories.", 'If you eat that you will die.'], 'source_input_ids': tensor([[   0, 3293,   83,  ...,    1,    1,    1],
#         [   0, 4263,  398,  ...,    1,    1,    1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ["C'est un livre d'histoires pour les enfants.", 'Si tu manges ça, tu vas mourir.'], 'target_input_ids': tensor([[  0, 313,  25,  ...,   1,   1,   1],
#         [  0, 602, 370,  ...,   1,   1,   1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2594:
# {'source_text': ['Do you want to buy this?', 'It was difficult for us to decide which one to buy.'], 'source_input_ids': tensor([[   0,  984,  398,  ...,    1,    1,    1],
#         [   0, 1650,  509,  ...,    1,    1,    1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ['Veux-tu acheter ceci ?', 'Il nous fut difficile de décider lequel choisir.'], 'target_input_ids': tensor([[    0,   310, 10999,  ...,     1,     1,     1],
#         [    0,   891,  2064,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2595:
# {'source_text': ['Will the weather be good tomorrow?', 'Watch out!'], 'source_input_ids': tensor([[    0, 20255,    70,  ...,     1,     1,     1],
#         [    0, 20413,  1810,  ...,     1,     1,     1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ["Est-ce qu'il ferra beau demain\xa0?", 'Attention !'], 'target_input_ids': tensor([[     0,  12566,      9,  ...,      1,      1,      1],
#         [     0, 172713,    711,  ...,      1,      1,      1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2596:
# {'source_text': ['She came to Japan for the purpose of studying Japanese.', "I'll see you again this afternoon."], 'source_input_ids': tensor([[    0,  4687, 21449,  ...,     1,     1,     1],
#         [    0,    87,    25,  ...,     1,     1,     1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ["Elle est venue au Japon dans le but d'étudier la langue japonaise.", 'Je te reverrai cette après-midi.'], 'target_input_ids': tensor([[    0, 14663,   437,  ...,     1,     1,     1],
#         [    0,   845,   120,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2597:
# {'source_text': ['You worked a lot this week.', 'Who are you supposed to be?'], 'source_input_ids': tensor([[    0,  2583, 79786,  ...,     1,     1,     1],
#         [    0, 40469,   621,  ...,     1,     1,     1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ['Vous avez beaucoup travaillé cette semaine.', 'Qui es-tu supposé être ?'], 'target_input_ids': tensor([[    0,  8459, 19116,  ...,     1,     1,     1],
#         [    0,  7644,   198,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2598:
# {'source_text': ['This is a very time-consuming task.', 'I want you to be my friend again.'], 'source_input_ids': tensor([[   0, 3293,   83,  ...,    1,    1,    1],
#         [   0,   87, 3444,  ...,    1,    1,    1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ["C'est une tâche chronophage.", 'Je veux que tu sois à nouveau mon ami.'], 'target_input_ids': tensor([[    0,   313,    25,  ...,     1,     1,     1],
#         [    0,   845, 54226,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2599:
# {'source_text': ["You're no longer welcome in my house.", 'He chose three beautiful roses for her.'], 'source_input_ids': tensor([[    0,  2583,    25,  ...,     1,     1,     1],
#         [    0,  1529, 19667,  ...,     1,     1,     1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ["Vous n'êtes plus le bienvenu chez moi.", 'Il choisit pour elle trois belles roses.'], 'target_input_ids': tensor([[    0,  8459,   653,  ...,     1,     1,     1],
#         [    0,   891, 60053,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2600:
# {'source_text': ["I won't allow you to date my sister.", 'How did you get to know her?'], 'source_input_ids': tensor([[    0,    87, 23742,  ...,     1,     1,     1],
#         [    0, 11249,  6777,  ...,     1,     1,     1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ['Je ne te permettrai pas de sortir avec ma sœur.', "Comment l'avez-vous connue\u202f?"], 'target_input_ids': tensor([[    0,   845,   108,  ...,     1,     1,     1],
#         [    0, 16277,    96,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2601:
# {'source_text': ['She helped cook lunch.', 'Please remember what he said.'], 'source_input_ids': tensor([[     0,   4687, 104902,  ...,      1,      1,      1],
#         [     0,  30607,  37629,  ...,      1,      1,      1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ['Elle aida à préparer le déjeuner.', "Veuillez vous rappeler ce qu'il a dit."], 'target_input_ids': tensor([[    0, 14663,    10,  ...,     1,     1,     1],
#         [    0,  2609, 68819,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2602:
# {'source_text': ['I was never told that I needed a visa.', "I'm a little dizzy."], 'source_input_ids': tensor([[  0,  87, 509,  ...,   1,   1,   1],
#         [  0,  87,  25,  ...,   1,   1,   1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ["On ne m'a jamais dit que j'avais besoin d'un visa.", "J'ai un peu la tête qui tourne."], 'target_input_ids': tensor([[   0, 2161,  108,  ...,    1,    1,    1],
#         [   0,  821,   25,  ...,    1,    1,    1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2603:
# {'source_text': ["Something happened here, but I don't know what.", "I can't get my money out of the bank today."], 'source_input_ids': tensor([[     0, 200905,  73659,  ...,      1,      1,      1],
#         [     0,     87,    831,  ...,      1,      1,      1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ["Quelque chose s'est produit ici, mais je ne sais pas quoi.", "Je ne peux pas retirer de l'argent de la banque aujourd'hui."], 'target_input_ids': tensor([[    0, 48556,   944,  ...,     1,     1,     1],
#         [    0,   845,   108,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2604:
# {'source_text': ['There is a bank in front of the hotel.', 'Few people are able to understand his theories.'], 'source_input_ids': tensor([[   0, 8622,   83,  ...,    1,    1,    1],
#         [   0, 4221,  434,  ...,    1,    1,    1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ["Il y a une banque devant l'hôtel.", 'Peu de gens sont capables de comprendre ses théories.'], 'target_input_ids': tensor([[   0,  891,  113,  ...,    1,    1,    1],
#         [   0, 1460,   34,  ...,    1,    1,    1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2605:
# {'source_text': ['Did I miss anything?', 'That would be a good idea.'], 'source_input_ids': tensor([[    0, 37307,    87,  ...,     1,     1,     1],
#         [    0,  9925,  2806,  ...,     1,     1,     1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ['Ai-je manqué quelque chose\u202f?', 'Ça serait une bonne idée.'], 'target_input_ids': tensor([[    0,  5860,     9,  ...,     1,     1,     1],
#         [    0, 25909, 39435,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2606:
# {'source_text': ['They were waiting for us.', "It's been a while since I've studied French."], 'source_input_ids': tensor([[    0, 10660,  3542,  ...,     1,     1,     1],
#         [    0,  1650,    25,  ...,     1,     1,     1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ['Elles nous attendaient.', "Ça fait un moment que je n'ai pas étudié le français."], 'target_input_ids': tensor([[     0, 125876,   2064,  ...,      1,      1,      1],
#         [     0,  25909,   3193,  ...,      1,      1,      1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2607:
# {'source_text': ["You're embarrassing me.", "Tom doesn't know a lot about animals."], 'source_input_ids': tensor([[    0,  2583,    25,  ...,     1,     1,     1],
#         [    0,  8352, 22027,  ...,     1,     1,     1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ["Vous me mettez mal à l'aise.", 'Tom ne sait pas grand chose sur les animaux.'], 'target_input_ids': tensor([[   0, 8459,  163,  ...,    1,    1,    1],
#         [   0, 8352,  108,  ...,    1,    1,    1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2608:
# {'source_text': ["She's a fox.", "Tom doesn't seem very interested."], 'source_input_ids': tensor([[    0,  4687,    25,  ...,     1,     1,     1],
#         [    0,  8352, 22027,  ...,     1,     1,     1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ["C'est un renard.", 'Tom ne semble pas très intéressé.'], 'target_input_ids': tensor([[   0,  313,   25,  ...,    1,    1,    1],
#         [   0, 8352,  108,  ...,    1,    1,    1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2609:
# {'source_text': ['How many of the words on this list do you know?', "Tom isn't able to come today."], 'source_input_ids': tensor([[    0, 11249,  5941,  ...,     1,     1,     1],
#         [    0,  8352, 56112,  ...,     1,     1,     1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ['Combien de mots sur cette liste connaissez-vous\xa0?', "Tom est dans l'incapacité de venir aujourd'hui."], 'target_input_ids': tensor([[     0, 106935,     33,  ...,      1,      1,      1],
#         [     0,   8352,    437,  ...,      1,      1,      1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2610:
# {'source_text': ['I should not have said that.', "We don't have to go."], 'source_input_ids': tensor([[   0,   87, 5608,  ...,    1,    1,    1],
#         [   0, 1401, 2301,  ...,    1,    1,    1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ["Je n'aurais pas dû dire cela.", 'Nous ne devons pas y aller.'], 'target_input_ids': tensor([[   0,  845,  653,  ...,    1,    1,    1],
#         [   0, 9529,  108,  ...,    1,    1,    1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2611:
# {'source_text': ['She won first prize in the speech contest.', 'Be polite to your parents.'], 'source_input_ids': tensor([[    0,  4687, 23742,  ...,     1,     1,     1],
#         [    0,   873, 30817,  ...,     1,     1,     1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ['Elle a gagné le premier prix au concours de diction.', 'Sois poli avec tes parents.'], 'target_input_ids': tensor([[    0, 14663,    10,  ...,     1,     1,     1],
#         [    0,  1061,   164,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2612:
# {'source_text': ['He is a man of wealth.', "If the car is gone, he can't be at the office."], 'source_input_ids': tensor([[   0, 1529,   83,  ...,    1,    1,    1],
#         [   0, 4263,   70,  ...,    1,    1,    1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ["C'est un homme riche.", "S'il n'y a plus la voiture, il ne peut pas être au bureau."], 'target_input_ids': tensor([[  0, 313,  25,  ...,   1,   1,   1],
#         [  0, 159,  25,  ...,   1,   1,   1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2613:
# {'source_text': ['I know where you live.', 'Bring me a glass of water, please.'], 'source_input_ids': tensor([[     0,     87,   3714,  ...,      1,      1,      1],
#         [     0, 166980,    163,  ...,      1,      1,      1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ['Je sais où tu habites.', "Apportez-moi un verre d'eau, s'il vous plaît."], 'target_input_ids': tensor([[    0,   845, 24855,  ...,     1,     1,     1],
#         [    0,  5787,  6982,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2614:
# {'source_text': ['Just get to work.', 'Put your hands in the air.'], 'source_input_ids': tensor([[    0,  9563,  2046,  ...,     1,     1,     1],
#         [    0, 19577,   935,  ...,     1,     1,     1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ['Mets-toi simplement au travail !', "Levez les mains en l'air."], 'target_input_ids': tensor([[   0, 4146,    7,  ...,    1,    1,    1],
#         [   0,  636, 9728,  ...,    1,    1,    1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2615:
# {'source_text': ['She put the children to bed.', 'I find the sound of the rain relaxing.'], 'source_input_ids': tensor([[   0, 4687, 3884,  ...,    1,    1,    1],
#         [   0,   87, 7413,  ...,    1,    1,    1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ['Elle a mis les enfants au lit.', 'Je trouve le bruit de la pluie apaisant.'], 'target_input_ids': tensor([[    0, 14663,    10,  ...,     1,     1,     1],
#         [    0,   845, 24215,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2616:
# {'source_text': ["I don't like meat.", 'Did you see a doctor?'], 'source_input_ids': tensor([[    0,    87,  2301,  ...,     1,     1,     1],
#         [    0, 37307,   398,  ...,     1,     1,     1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ["Je n'aime pas la viande.", 'As-tu vu un docteur\u202f?'], 'target_input_ids': tensor([[   0,  845,  653,  ...,    1,    1,    1],
#         [   0, 1301,    9,  ...,    1,    1,    1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2617:
# {'source_text': ['I hate lawyers.', "Tom noticed Mary wasn't wearing the ring he'd given her."], 'source_input_ids': tensor([[     0,     87,  35463,  ...,      1,      1,      1],
#         [     0,   8352, 156672,  ...,      1,      1,      1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ['Je déteste les avocats.', "Tom remarqua que Mary ne portait pas la bague qu'il lui avait donnée."], 'target_input_ids': tensor([[    0,   845, 52635,  ...,     1,     1,     1],
#         [    0,  8352,   456,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2618:
# {'source_text': ['Please speak louder so everybody can hear you.', 'Is this your bicycle?'], 'source_input_ids': tensor([[    0, 30607, 70424,  ...,     1,     1,     1],
#         [    0,  2071,   903,  ...,     1,     1,     1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ["S'il vous plaît, parlez plus fort pour que tout le monde vous entende.", 'Est-ce ton vélo\u202f?'], 'target_input_ids': tensor([[    0,   159,    25,  ...,     1,     1,     1],
#         [    0, 12566,     9,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2619:
# {'source_text': ['I want to see the director of the company.', "You can take a horse to water, but you can't make him drink."], 'source_input_ids': tensor([[   0,   87, 3444,  ...,    1,    1,    1],
#         [   0, 2583,  831,  ...,    1,    1,    1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ['Je veux voir le directeur de la société.', 'Tu auras beau amener le cheval à la rivière, mais tu ne le feras pas boire pour autant.'], 'target_input_ids': tensor([[    0,   845, 54226,  ...,     1,     1,     1],
#         [    0,  1371, 37450,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2620:
# {'source_text': ["I borrowed my father's hammer to build a dog house.", 'You are cleared for takeoff.'], 'source_input_ids': tensor([[   0,   87, 3017,  ...,    1,    1,    1],
#         [   0, 2583,  621,  ...,    1,    1,    1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ["J'ai emprunté le marteau de mon père pour construire une niche.", 'Votre décollage est confirmé.'], 'target_input_ids': tensor([[     0,    821,     25,  ...,      1,      1,      1],
#         [     0, 114324,  74121,  ...,      1,      1,      1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2621:
# {'source_text': ['I made this doghouse by myself.', 'I bought flowers because my grandmother is coming today for a visit.'], 'source_input_ids': tensor([[     0,     87,   7228,  ...,      1,      1,      1],
#         [     0,     87, 123997,  ...,      1,      1,      1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ["J'ai moi-même construit cette niche.", "J'ai acheté des fleurs car ma grand-mère vient me rendre visite aujourd'hui."], 'target_input_ids': tensor([[  0, 821,  25,  ...,   1,   1,   1],
#         [  0, 821,  25,  ...,   1,   1,   1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2622:
# {'source_text': ["Tom, I'm happy for you.", 'Tom is kind to everybody.'], 'source_input_ids': tensor([[   0, 8352,    4,  ...,    1,    1,    1],
#         [   0, 8352,   83,  ...,    1,    1,    1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ['Tom, je suis heureuse pour toi.', 'Tom est aimable avec tout le monde.'], 'target_input_ids': tensor([[   0, 8352,    4,  ...,    1,    1,    1],
#         [   0, 8352,  437,  ...,    1,    1,    1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2623:
# {'source_text': ['We are all happy to help.', 'Everyone should go.'], 'source_input_ids': tensor([[     0,   1401,    621,  ...,      1,      1,      1],
#         [     0, 191096,   5608,  ...,      1,      1,      1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ["Nous sommes tous contents d'aider.", 'Tout le monde devrait partir.'], 'target_input_ids': tensor([[    0,  9529, 34120,  ...,     1,     1,     1],
#         [    0, 31051,    95,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2624:
# {'source_text': ['I thought we had more time.', 'How are your parents?'], 'source_input_ids': tensor([[    0,    87, 17569,  ...,     1,     1,     1],
#         [    0, 11249,   621,  ...,     1,     1,     1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ['Je pensais que nous disposions de davantage de temps.', 'Comment vont vos parents ?'], 'target_input_ids': tensor([[    0,   845, 14946,  ...,     1,     1,     1],
#         [    0, 16277, 72581,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2625:
# {'source_text': ["You're awesome.", 'I often perform in nightclubs.'], 'source_input_ids': tensor([[    0,  2583,    25,  ...,     1,     1,     1],
#         [    0,    87, 27983,  ...,     1,     1,     1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ['Tu es géniale.', 'Je me produis souvent dans les boites de nuit.'], 'target_input_ids': tensor([[   0, 1371,  198,  ...,    1,    1,    1],
#         [   0,  845,  163,  ...,    1,    1,    1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2626:
# {'source_text': ["Why don't you ask your boyfriend?", 'Generally speaking, the climate of Japan is mild.'], 'source_input_ids': tensor([[    0, 44084,  2301,  ...,     1,     1,     1],
#         [    0,  9082,   538,  ...,     1,     1,     1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ['Pourquoi ne demandes-tu pas à ton petit ami ?', "Dans l'ensemble, le Japon a un climat doux."], 'target_input_ids': tensor([[     0, 104552,    108,  ...,      1,      1,      1],
#         [     0,  12612,     96,  ...,      1,      1,      1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2627:
# {'source_text': ["Tom won't let you down.", 'Cats can see even in dark places.'], 'source_input_ids': tensor([[    0,  8352, 23742,  ...,     1,     1,     1],
#         [    0, 18826,     7,  ...,     1,     1,     1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ['Tom ne te laissera pas tomber.', 'Les chats peuvent voir même dans les endroits sombres.'], 'target_input_ids': tensor([[   0, 8352,  108,  ...,    1,    1,    1],
#         [   0, 1734, 3245,  ...,    1,    1,    1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2628:
# {'source_text': ['Do you think your parents spent enough time with you when you were in your teens?', 'I let the cat out of the house.'], 'source_input_ids': tensor([[   0,  984,  398,  ...,    1,    1,    1],
#         [   0,   87, 2633,  ...,    1,    1,    1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ['Pensez-vous que vos parents ont passé suffisamment de temps avec vous lorsque vous étiez adolescente ?', "J'ai laissé la chatte hors de la maison."], 'target_input_ids': tensor([[   0, 4267,    7,  ...,    1,    1,    1],
#         [   0,  821,   25,  ...,    1,    1,    1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2629:
# {'source_text': ['I wish the fedora would come back in style.', 'Please obey the school rules.'], 'source_input_ids': tensor([[    0,    87, 32599,  ...,     1,     1,     1],
#         [    0, 30607,    36,  ...,     1,     1,     1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ["J'aimerais que le chapeau mou revienne à la mode.", "Veuillez obéir au règlement de l'école."], 'target_input_ids': tensor([[    0,   821,    25,  ...,     1,     1,     1],
#         [    0,  2609, 68819,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2630:
# {'source_text': ['They love Tom.', 'Is Tom a good kisser?'], 'source_input_ids': tensor([[    0, 10660,  5161,  ...,     1,     1,     1],
#         [    0,  2071,  8352,  ...,     1,     1,     1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ['Ils aiment Tom.', 'Est-ce que Tom embrasse bien\xa0?'], 'target_input_ids': tensor([[    0, 42187,  1300,  ...,     1,     1,     1],
#         [    0, 12566,     9,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2631:
# {'source_text': ['I know how to fly.', "Why don't you stay there?"], 'source_input_ids': tensor([[    0,    87,  3714,  ...,     1,     1,     1],
#         [    0, 44084,  2301,  ...,     1,     1,     1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ['Je sais voler.', 'Pourquoi ne restes-tu pas là ?'], 'target_input_ids': tensor([[     0,    845,  24855,  ...,      1,      1,      1],
#         [     0, 104552,    108,  ...,      1,      1,      1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2632:
# {'source_text': ['Does that surprise you?', 'She cursed him for forgetting his promise.'], 'source_input_ids': tensor([[     0, 101790,    450,  ...,      1,      1,      1],
#         [     0,   4687,  22074,  ...,      1,      1,      1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ['Est-ce que ça te surprend\xa0?', 'Elle le maudit pour avoir oublié sa promesse.'], 'target_input_ids': tensor([[    0, 12566,     9,  ...,     1,     1,     1],
#         [    0, 14663,    95,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2633:
# {'source_text': ['She persuaded him to do it.', 'How did this happen?'], 'source_input_ids': tensor([[    0,  4687,   117,  ...,     1,     1,     1],
#         [    0, 11249,  6777,  ...,     1,     1,     1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ['Elle le persuada de le faire.', 'Comment cela est-il survenu ?'], 'target_input_ids': tensor([[    0, 14663,    95,  ...,     1,     1,     1],
#         [    0, 16277, 10804,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2634:
# {'source_text': ["Don't you see what's happened?", 'My cat is black.'], 'source_input_ids': tensor([[   0, 7650,   25,  ...,    1,    1,    1],
#         [   0, 2646, 7515,  ...,    1,    1,    1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ["Ne vois-tu pas ce qui s'est produit ?", 'Ma chatte est noire.'], 'target_input_ids': tensor([[    0,   799, 81516,  ...,     1,     1,     1],
#         [    0,   911,  3245,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2635:
# {'source_text': ['She gave me a meaningful look.', 'Tom used to eat a lot of meat.'], 'source_input_ids': tensor([[    0,  4687, 26038,  ...,     1,     1,     1],
#         [    0,  8352, 11814,  ...,     1,     1,     1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ["Elle m'a jeté un regard plein de signification.", 'Tom avait pour habitude de manger beaucoup de viande.'], 'target_input_ids': tensor([[    0, 14663,   347,  ...,     1,     1,     1],
#         [    0,  8352, 17095,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2636:
# {'source_text': ['You raise a good point.', 'She lives in the village.'], 'source_input_ids': tensor([[     0,   2583, 138804,  ...,      1,      1,      1],
#         [     0,   4687,  60742,  ...,      1,      1,      1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ['Tu soulèves un bon point.', 'Elle vit dans ce village.'], 'target_input_ids': tensor([[    0,  1371, 57289,  ...,     1,     1,     1],
#         [    0, 14663, 12508,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2637:
# {'source_text': ["We've got our own way of doing things.", 'You can wait for me here.'], 'source_input_ids': tensor([[   0, 1401,   25,  ...,    1,    1,    1],
#         [   0, 2583,  831,  ...,    1,    1,    1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ['Nous avons notre propre façon de faire les choses.', "Tu peux m'attendre ici."], 'target_input_ids': tensor([[    0,  9529, 21053,  ...,     1,     1,     1],
#         [    0,  1371, 38160,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2638:
# {'source_text': ['I know Tom is a con artist.', 'He ran away with the money.'], 'source_input_ids': tensor([[    0,    87,  3714,  ...,     1,     1,     1],
#         [    0,  1529, 13028,  ...,     1,     1,     1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ['Je sais que Tom est un arnaqueur.', "Il s'est enfui avec l'argent."], 'target_input_ids': tensor([[    0,   845, 24855,  ...,     1,     1,     1],
#         [    0,   891,    91,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2639:
# {'source_text': ['You need to come home.', 'How do you live like this?'], 'source_input_ids': tensor([[    0,  2583,  3871,  ...,     1,     1,     1],
#         [    0, 11249,    54,  ...,     1,     1,     1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ['Il te faut venir à la maison.', 'Comment vivre ainsi ?'], 'target_input_ids': tensor([[    0,   891,   120,  ...,     1,     1,     1],
#         [    0, 16277, 64499,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2640:
# {'source_text': ['Did I wake you?', "We haven't had a price increase in the last five years."], 'source_input_ids': tensor([[    0, 37307,    87,  ...,     1,     1,     1],
#         [    0,  1401, 38246,  ...,     1,     1,     1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ["T'ai-je réveillée ?", "Nous n'avons pas connu d'augmentation de prix dans les cinq dernières années."], 'target_input_ids': tensor([[   0,  384,   25,  ...,    1,    1,    1],
#         [   0, 9529,  653,  ...,    1,    1,    1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2641:
# {'source_text': ["That's a good move.", "I failed to recall the song's title."], 'source_input_ids': tensor([[     0,   9925,     25,  ...,      1,      1,      1],
#         [     0,     87, 165523,  ...,      1,      1,      1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ["C'est un bon coup.", "Je n'ai pas pu me rappeler le titre de la chanson."], 'target_input_ids': tensor([[  0, 313,  25,  ...,   1,   1,   1],
#         [  0, 845, 653,  ...,   1,   1,   1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2642:
# {'source_text': ["I don't understand why I need to go to your house at midnight.", 'This coat is warm.'], 'source_input_ids': tensor([[   0,   87, 2301,  ...,    1,    1,    1],
#         [   0, 3293, 5798,  ...,    1,    1,    1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ["Je ne comprends pas pourquoi il faut que j'aille chez toi à minuit.", 'Ce manteau est chaud.'], 'target_input_ids': tensor([[   0,  845,  108,  ...,    1,    1,    1],
#         [   0, 1845,  332,  ...,    1,    1,    1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2643:
# {'source_text': ['Which is your luggage?', "Everyone's out."], 'source_input_ids': tensor([[     0, 130078,     83,  ...,      1,      1,      1],
#         [     0, 191096,     25,  ...,      1,      1,      1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ['Quelle est ta valise ?', 'Tout le monde est dehors.'], 'target_input_ids': tensor([[    0, 59528,   437,  ...,     1,     1,     1],
#         [    0, 31051,    95,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2644:
# {'source_text': ['I wonder if we could talk.', 'Tom ate a lot more than me.'], 'source_input_ids': tensor([[    0,    87, 32195,  ...,     1,     1,     1],
#         [    0,  8352,    10,  ...,     1,     1,     1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ['Je me demande si nous pourrions discuter.', 'Tom mangea beaucoup plus que moi.'], 'target_input_ids': tensor([[   0,  845,  163,  ...,    1,    1,    1],
#         [   0, 8352, 2918,  ...,    1,    1,    1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2645:
# {'source_text': ['I am poor at tennis.', 'I really am sorry.'], 'source_input_ids': tensor([[   0,   87,  444,  ...,    1,    1,    1],
#         [   0,   87, 6183,  ...,    1,    1,    1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ['Je suis médiocre au tennis.', 'Je suis vraiment désolé.'], 'target_input_ids': tensor([[   0,  845, 5189,  ...,    1,    1,    1],
#         [   0,  845, 5189,  ...,    1,    1,    1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2646:
# {'source_text': ["How's the weather there?", 'Where did you park the car?'], 'source_input_ids': tensor([[    0, 11249,    25,  ...,     1,     1,     1],
#         [    0, 78662,  6777,  ...,     1,     1,     1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ['Comment est le temps là-bas\u202f?', 'Où avez-vous garé la voiture ?'], 'target_input_ids': tensor([[    0, 16277,   437,  ...,     1,     1,     1],
#         [    0,   180,  8612,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2647:
# {'source_text': ["I'd like to live in New York.", 'What a remarkable performance!'], 'source_input_ids': tensor([[   0,   87,   25,  ...,    1,    1,    1],
#         [   0, 4865,   10,  ...,    1,    1,    1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ["J'aimerais vivre à New York.", 'Quelle exécution remarquable !'], 'target_input_ids': tensor([[    0,   821,    25,  ...,     1,     1,     1],
#         [    0, 59528,     6,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2648:
# {'source_text': ['He introduced his sister to me.', 'Did it make you angry?'], 'source_input_ids': tensor([[    0,  1529, 65508,  ...,     1,     1,     1],
#         [    0, 37307,   442,  ...,     1,     1,     1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ["Il m'a présenté sa sœur.", "Cela t'a-t-il mis en colère ?"], 'target_input_ids': tensor([[    0,   891,   347,  ...,     1,     1,     1],
#         [    0, 37060,   808,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2649:
# {'source_text': ['I made a big mistake.', 'My knee hurts a lot.'], 'source_input_ids': tensor([[   0,   87, 7228,  ...,    1,    1,    1],
#         [   0, 2646,  472,  ...,    1,    1,    1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ["J'ai commis une grosse erreur.", 'Mon genou me fait très mal.'], 'target_input_ids': tensor([[    0,   821,    25,  ...,     1,     1,     1],
#         [    0,  7465, 62614,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2650:
# {'source_text': ['What do you remember?', 'I could swim faster when I was young.'], 'source_input_ids': tensor([[   0, 4865,   54,  ...,    1,    1,    1],
#         [   0,   87, 5809,  ...,    1,    1,    1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ['De quoi te souviens-tu ?', "Je nageais plus vite quand j'étais jeune."], 'target_input_ids': tensor([[    0,   262, 30100,  ...,     1,     1,     1],
#         [    0,   845,    24,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2651:
# {'source_text': ['He has no more strength.', 'Is that going to happen soon?'], 'source_input_ids': tensor([[   0, 1529, 1556,  ...,    1,    1,    1],
#         [   0, 2071,  450,  ...,    1,    1,    1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ["Il n'a plus de force.", 'Cela va-t-il se produire bientôt ?'], 'target_input_ids': tensor([[    0,   891,   653,  ...,     1,     1,     1],
#         [    0, 37060,   307,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2652:
# {'source_text': ['Are we broke?', "You can't have this."], 'source_input_ids': tensor([[    0, 15901,   642,  ...,     1,     1,     1],
#         [    0,  2583,   831,  ...,     1,     1,     1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ['Sommes-nous fauchées ?', 'Tu ne peux pas avoir ça.'], 'target_input_ids': tensor([[   0, 4961, 3716,  ...,    1,    1,    1],
#         [   0, 1371,  108,  ...,    1,    1,    1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2653:
# {'source_text': ['Please wash my back.', 'The elevator stopped on the second floor.'], 'source_input_ids': tensor([[     0,  30607,    509,  ...,      1,      1,      1],
#         [     0,    581, 154630,  ...,      1,      1,      1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ["Nettoie mon dos s'il te plaît.", "L'ascenseur s'est arrêté au deuxième étage."], 'target_input_ids': tensor([[    0, 43268,    31,  ...,     1,     1,     1],
#         [    0,   339,    25,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 2654:
# {'source_text': ['Are you busy Friday night?', 'He asked her to marry him and she accepted his proposal.'], 'source_input_ids': tensor([[    0, 15901,   398,  ...,     1,     1,     1],
#         [    0,  1529, 37170,  ...,     1,     1,     1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ['Êtes-vous occupé vendredi soir ?', "Il lui a demandé de l'épouser et elle a accepté sa demande."], 'target_input_ids': tensor([[    0, 54478,  1636,  ...,     1,     1,     1],
#         [    0,   891,  1869,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
# ...
# <class 'dict'>
# Batch 3290:
# {'source_text': ['How could we not win?', 'All I found is a pair of scissors.'], 'source_input_ids': tensor([[    0, 11249,  5809,  ...,     1,     1,     1],
#         [    0,  3164,    87,  ...,     1,     1,     1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ['Comment pourrions-nous ne pas gagner ?', "Tout ce que j'ai trouvé, c'est une paire de ciseaux."], 'target_input_ids': tensor([[    0, 16277,   578,  ...,     1,     1,     1],
#         [    0, 31051,   405,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 3291:
# {'source_text': ['When are we going to land?', 'I had a son who died in the war.'], 'source_input_ids': tensor([[    0, 14847,   621,  ...,     1,     1,     1],
#         [    0,    87,  1902,  ...,     1,     1,     1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ['Quand allons-nous atterrir\xa0?', "J'avais un fils qui est mort à la guerre."], 'target_input_ids': tensor([[     0,  68382, 167182,  ...,      1,      1,      1],
#         [     0,    821,     25,  ...,      1,      1,      1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 3292:
# {'source_text': ["I don't know where he is or what he's doing.", 'He can be relied on.'], 'source_input_ids': tensor([[   0,   87, 2301,  ...,    1,    1,    1],
#         [   0, 1529,  831,  ...,    1,    1,    1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ["Je ne sais ni où il est ni ce qu'il fait.", 'On peut se fier à lui.'], 'target_input_ids': tensor([[   0,  845,  108,  ...,    1,    1,    1],
#         [   0, 2161, 4372,  ...,    1,    1,    1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 3293:
# {'source_text': ['Tom talked all night.', "In all probability, we'll arrive before them."], 'source_input_ids': tensor([[    0,  8352, 22120,  ...,     1,     1,     1],
#         [    0,   360,   756,  ...,     1,     1,     1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ['Tom parla toute la nuit.', 'Selon toute probabilité, nous arriverons avant eux.'], 'target_input_ids': tensor([[     0,   8352,  26400,  ...,      1,      1,      1],
#         [     0, 123782,  13725,  ...,      1,      1,      1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 3294:
# {'source_text': ["If I were you, I'd buy it.", 'What did Tom say he lost?'], 'source_input_ids': tensor([[   0, 4263,   87,  ...,    1,    1,    1],
#         [   0, 4865, 6777,  ...,    1,    1,    1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ["Si j'étais toi, je l'acquerrais.", "Qu'est-ce que Tom a dit avoir perdu ?"], 'target_input_ids': tensor([[    0,   602,  1647,  ...,     1,     1,     1],
#         [    0, 10022,    25,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 3295:
# {'source_text': ['My mother still calls me Tom.', 'Do you live here?'], 'source_input_ids': tensor([[    0,  2646, 42732,  ...,     1,     1,     1],
#         [    0,   984,   398,  ...,     1,     1,     1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ["Ma mère m'appelle toujours Tom.", 'Résides-tu ici ?'], 'target_input_ids': tensor([[    0,   911, 94683,  ...,     1,     1,     1],
#         [    0, 18436,  8752,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 3296:
# {'source_text': ['I have to pull a ripcord to start my lawn mower.', 'Call me back.'], 'source_input_ids': tensor([[    0,    87,   765,  ...,     1,     1,     1],
#         [    0, 26265,   163,  ...,     1,     1,     1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ['Je dois tirer sur une cordelette de démarrage pour lancer ma tondeuse.', 'Rappelle-moi.'], 'target_input_ids': tensor([[     0,    845,  13479,  ...,      1,      1,      1],
#         [     0,    627, 111342,  ...,      1,      1,      1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 3297:
# {'source_text': ["I'm not wearing this.", 'Every time they talk, they argue.'], 'source_input_ids': tensor([[    0,    87,    25,  ...,     1,     1,     1],
#         [    0, 87769,  1733,  ...,     1,     1,     1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ['Je ne vais pas porter ça.', "À chaque fois qu'ils discutent, ils se disputent."], 'target_input_ids': tensor([[    0,   845,   108,  ...,     1,     1,     1],
#         [    0, 19597, 19249,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 3298:
# {'source_text': ["I'll wait till noon.", 'Anybody see you?'], 'source_input_ids': tensor([[    0,    87,    25,  ...,     1,     1,     1],
#         [    0, 28541, 37873,  ...,     1,     1,     1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ["J'attendrai jusqu'à midi.", "Quiconque t'a vu ?"], 'target_input_ids': tensor([[   0,  821,   25,  ...,    1,    1,    1],
#         [   0, 7644, 2271,  ...,    1,    1,    1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 3299:
# {'source_text': ['I want a challenge.', "I'll hang onto it for now."], 'source_input_ids': tensor([[   0,   87, 3444,  ...,    1,    1,    1],
#         [   0,   87,   25,  ...,    1,    1,    1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ['Je veux un défi.', "Je vais le conserver pour l'instant."], 'target_input_ids': tensor([[    0,   845, 54226,  ...,     1,     1,     1],
#         [    0,   845, 19755,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 3300:
# {'source_text': ['I can rely on Tom.', 'My kids bought me this.'], 'source_input_ids': tensor([[    0,    87,   831,  ...,     1,     1,     1],
#         [    0,  2646, 34376,  ...,     1,     1,     1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ["Je peux m'appuyer sur Tom.", "Mes enfants m'ont acheté ceci."], 'target_input_ids': tensor([[    0,   845, 38160,  ...,     1,     1,     1],
#         [    0, 12021, 21175,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 3301:
# {'source_text': ['I really think we should talk.', 'I rang the bell.'], 'source_input_ids': tensor([[    0,    87,  6183,  ...,     1,     1,     1],
#         [    0,    87, 17163,  ...,     1,     1,     1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ['Je pense vraiment que nous devrions parler.', 'Je fis résonner la cloche.'], 'target_input_ids': tensor([[    0,   845, 19067,  ...,     1,     1,     1],
#         [    0,   845, 43894,  ...,     1,     1,     1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 3302:
# {'source_text': ['My father takes a walk every day.', 'Are we just friends?'], 'source_input_ids': tensor([[    0,  2646, 67373,  ...,     1,     1,     1],
#         [    0, 15901,   642,  ...,     1,     1,     1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ['Mon père se promène tous les jours.', "Ne sommes-nous qu'amis ?"], 'target_input_ids': tensor([[     0,   7465, 103010,  ...,      1,      1,      1],
#         [     0,    799,  34120,  ...,      1,      1,      1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 3303:
# {'source_text': ["I can't believe he kissed you.", "I'm still not satisfied."], 'source_input_ids': tensor([[  0,  87, 831,  ...,   1,   1,   1],
#         [  0,  87,  25,  ...,   1,   1,   1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ["Je ne parviens pas à croire qu'il vous ait embrassée.", 'Je ne suis toujours pas satisfait.'], 'target_input_ids': tensor([[  0, 845, 108,  ...,   1,   1,   1],
#         [  0, 845, 108,  ...,   1,   1,   1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# Batch 3304:
# {'source_text': ["I can't join you.", 'That box is bigger than this one.'], 'source_input_ids': tensor([[    0,    87,   831,  ...,     1,     1,     1],
#         [    0,  9925, 16530,  ...,     1,     1,     1]]), 'source_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]]), 'target_text': ['Je ne peux me joindre à vous.', 'Cette boîte-là est plus grande que celle-ci.'], 'target_input_ids': tensor([[     0,    845,    108,  ...,      1,      1,      1],
#         [     0,  20097, 179375,  ...,      1,      1,      1]]), 'target_mask': tensor([[ True,  True,  True,  ..., False, False, False],
#         [ True,  True,  True,  ..., False, False, False]])}
# <class 'dict'>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-536ec0382c7c> in <cell line: 1>()
# ----> 1 for i, data in enumerate(dataloader):
#       2     print(f"Batch {i+1}:")
#       3     print(data)
#       4     print(type(data))
#       5     # print(data.shape)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     629                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630                 self._reset()  # type: ignore[call-arg]
# --> 631             data = self._next_data()
#     632             self._num_yielded += 1
#     633             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     673     def _next_data(self):
#     674         index = self._next_index()  # may raise StopIteration
# --> 675         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676         if self._pin_memory:
#     677             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      49                 data = self.dataset.__getitems__(possibly_batched_index)
#      50             else:
# ---> 51                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      49                 data = self.dataset.__getitems__(possibly_batched_index)
#      50             else:
# ---> 51                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
#
# <ipython-input-3-a4afd2008405> in __getitem__(self, idx)
#       9
#      10     def __getitem__(self, idx):
# ---> 11         source = self.dataframe.iloc[idx][english]
#      12         target = self.dataframe.iloc[idx][french]
#      13
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1101
#    1102             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103             return self._getitem_axis(maybe_callable, axis=axis)
#    1104
#    1105     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1656             self._validate_integer(key, axis)
#    1657
# -> 1658             return self.obj._ixs(key, axis=axis)
#    1659
#    1660     def _get_slice_axis(self, slice_obj: slice, axis: AxisInt):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _ixs(self, i, axis)
#    3654             # if we are a copy, mark as such
#    3655             copy = isinstance(new_mgr.array, np.ndarray) and new_mgr.array.base is None
# -> 3656             result = self._constructor_sliced(new_mgr, name=self.index[i]).__finalize__(
#    3657                 self
#    3658             )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     389                 object.__setattr__(self, "_name", name)
#     390             else:
# --> 391                 self.name = name
#     392             return
#     393
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    6009             object.__setattr__(self, name, value)
#    6010         elif name in self._metadata:
# -> 6011             object.__setattr__(self, name, value)
#    6012         else:
#    6013             try:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in name(self, value)
#     671     @name.setter
#     672     def name(self, value: Hashable) -> None:
# --> 673         validate_all_hashable(value, error_name=f"{type(self).__name__}.name")
#     674         object.__setattr__(self, "_name", value)
#     675
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/common.py in validate_all_hashable(error_name, *args)
#    1648     None
#    1649     """
# -> 1650     if not all(is_hashable(arg) for arg in args):
#    1651         if error_name:
#    1652             raise TypeError(f"{error_name} must be a hashable type")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/common.py in <genexpr>(.0)
#    1648     None
#    1649     """
# -> 1650     if not all(is_hashable(arg) for arg in args):
#    1651         if error_name:
#    1652             raise TypeError(f"{error_name} must be a hashable type")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/inference.py in is_hashable(obj)
#     358
#     359     try:
# --> 360         hash(obj)
#     361     except TypeError:
#     362         return False
#
# KeyboardInterrupt:

# %%
def train(dataloader, model, loss_fn, optimizer, device):
    print('Training...')
    model.train()
    total_loss = 0

    for batch in dataloader:
        src = batch['source_input_ids'].to(device)
        print(src)
        tgt = batch['target_input_ids'].to(device)
        src_mask = batch['source_mask'].to(device)
        tgt_mask = batch['target_mask'].to(device)

        # Transpose masks to match the expected shape [seq_length, batch_size]
        # src = src.t()
        # tgt = tgt.t()
        src_mask = src_mask.t()
        tgt_mask = tgt_mask.t()


        # src_key_padding_mask = src_mask.t()
        # tgt_key_padding_mask = tsrc_mask.t()
        # src_key_padding_mask = src_mask.t()
        # tgt_key_padding_mask = tgt_mask.t()

        optimizer.zero_grad()

        output = model(src, tgt, src_key_padding_mask=src_mask, tgt_key_padding_mask=tgt_mask)
        # print(output)
        output = output.reshape(-1, output.shape[-1])  # Flatten output for loss calculation
        tgt = tgt.reshape(-1)  # Flatten target for loss calculation

        loss = loss_fn(output, tgt)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        print (total_loss)

    average_loss = total_loss / len(dataloader)
    print(f"Average Loss: {average_loss}")

# %%
# Assuming the use of a CUDA device if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# Example of running the training loop
train(dataloader, model, loss_fn, optimizer, device)
# Out:
# Training...
# tensor([[    0,  8352, 43240,  ...,     1,     1,     1],
#         [    0,    87, 38246,  ...,     1,     1,     1]], device='cuda:0')
# nan
# tensor([[    0, 59488,  8352,  ...,     1,     1,     1],
#         [    0,  4263,   398,  ...,     1,     1,     1]], device='cuda:0')
# nan
# tensor([[   0,   87, 8306,  ...,    1,    1,    1],
#         [   0,   87, 2301,  ...,    1,    1,    1]], device='cuda:0')
# nan
# tensor([[   0, 4687,   83,  ...,    1,    1,    1],
#         [   0,   87, 3714,  ...,    1,    1,    1]], device='cuda:0')
# nan
# tensor([[   0,   87, 3444,  ...,    1,    1,    1],
#         [   0,   87,   25,  ...,    1,    1,    1]], device='cuda:0')
# nan
# tensor([[    0,  1401,  1221,  ...,     1,     1,     1],
#         [    0,  2646, 17155,  ...,     1,     1,     1]], device='cuda:0')
# nan
# tensor([[   0, 1529,   83,  ...,    1,    1,    1],
#         [   0,   87,   25,  ...,    1,    1,    1]], device='cuda:0')
# nan
# tensor([[    0,    87,    25,  ...,     1,     1,     1],
#         [    0, 59023,   214,  ...,     1,     1,     1]], device='cuda:0')
# nan
# tensor([[   0, 4865, 6777,  ...,    1,    1,    1],
#         [   0, 8622,  509,  ...,    1,    1,    1]], device='cuda:0')
# nan
# tensor([[     0,     87,     25,  ...,      1,      1,      1],
#         [     0,   1529, 174176,  ...,      1,      1,      1]],
#        device='cuda:0')
# nan
# tensor([[     0,   2583,  69427,  ...,      1,      1,      1],
#         [     0,   1529, 171332,  ...,      1,      1,      1]],
#        device='cuda:0')
# nan
# tensor([[   0, 1529, 1556,  ...,    1,    1,    1],
#         [   0,   87,  444,  ...,    1,    1,    1]], device='cuda:0')
# nan
# tensor([[    0,  7650,    25,  ...,     1,     1,     1],
#         [    0, 10660,  6713,  ...,     1,     1,     1]], device='cuda:0')
# nan
# tensor([[     0, 113132,      7,  ...,      1,      1,      1],
#         [     0,   4687,   1556,  ...,      1,      1,      1]],
#        device='cuda:0')
# nan
# tensor([[    0,  4687, 72856,  ...,     1,     1,     1],
#         [    0,   581, 51521,  ...,     1,     1,     1]], device='cuda:0')
# nan
# tensor([[    0, 30097,  9319,  ...,     1,     1,     1],
#         [    0,    87,    25,  ...,     1,     1,     1]], device='cuda:0')
# nan
# tensor([[    0,  4171,   398,  ...,     1,     1,     1],
#         [    0,   581, 24284,  ...,     1,     1,     1]], device='cuda:0')
# nan
# tensor([[    0,    87, 38246,  ...,     1,     1,     1],
#         [    0,  2583,  8110,  ...,     1,     1,     1]], device='cuda:0')
# nan
# tensor([[    0, 11249,  5941,  ...,     1,     1,     1],
#         [    0,   717, 14192,  ...,     1,     1,     1]], device='cuda:0')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-8075f9c163b2> in <cell line: 6>()
#       4
#       5 # Example of running the training loop
# ----> 6 train(dataloader, model, loss_fn, optimizer, device)
#
# <ipython-input-10-637ddcd13a48> in train(dataloader, model, loss_fn, optimizer, device)
#      34         optimizer.step()
#      35
# ---> 36         total_loss += loss.item()
#      37         print (total_loss)
#      38
#
# KeyboardInterrupt:

# %%
def main():
    # Tokenization
    tokenizer = XLMRobertaTokenizer.from_pretrained('xlm-roberta-base');
    vocab_size = tokenizer.vocab_size
    # Data Preparation
    dataset = English2FrenchDataset('eng_french.csv', tokenizer, context_window)
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)
    # Model
    model = Model(vocab_size, embedding_size, nhead, num_encoder_layers, num_decoder_layers, dim_feedforward, context_window, dropout)
    # Loss
    loss_fn = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.0001)
    # Training
    def train(dataloader, model, loss_fn, optimizer, device):
        print('training')
        model.train()  # Ensure model is in training mode
        total_loss = 0

        for src, tgt in dataloader:
            # Move data to the appropriate device (e.g., GPU)
            src = src.to(device)
            tgt = tgt.to(device)

            # Create masks for padding in source and target
            src_mask = src != 0
            tgt_mask = tgt != 0
            src_key_padding_mask = ~src_mask
            tgt_key_padding_mask = ~tgt_mask

            # Clear previous gradients
            optimizer.zero_grad()

            # Forward pass: compute predictions
            output = model(src, tgt, src_key_padding_mask, tgt_key_padding_mask)
            output = output.reshape(-1, output.shape[-1])  # Flatten output for loss calculation
            tgt = tgt.reshape(-1)  # Flatten target for loss calculation

            # Compute loss
            loss = loss_fn(output, tgt)
            loss.backward()  # Backpropagation
            optimizer.step()  # Update model parameters

            # Aggregate loss
            total_loss += loss.item()

            # Compute average loss
            average_loss = total_loss / len(dataloader)
            print(f"Average Loss: {average_loss}")


    # Assuming the use of a CUDA device if available
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)

    # Example of running the training loop
    train(dataloader, model, loss_fn, optimizer, device)

if __name__ == "__main__":
    main()
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:286: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# training
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-3bc253691882> in <cell line: 58>()
#      57
#      58 if __name__ == "__main__":
# ---> 59     main()
#
# <ipython-input-18-3bc253691882> in main()
#      54
#      55     # Example of running the training loop
# ---> 56     train(dataloader, model, loss_fn, optimizer, device)
#      57
#      58 if __name__ == "__main__":
#
# <ipython-input-18-3bc253691882> in train(dataloader, model, loss_fn, optimizer, device)
#      17         total_loss = 0
#      18
# ---> 19         for src, tgt in dataloader:
#      20             # Move data to the appropriate device (e.g., GPU)
#      21             src = src.to(device)
#
# ValueError: too many values to unpack (expected 2)
